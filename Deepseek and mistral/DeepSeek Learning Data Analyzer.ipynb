# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\vemer\Downloads\titanic dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\vemer\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\vemer\anaconda3\lib\site-packages (from ollama) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\vemer\anaconda3\lib\site-packages (from ollama) (2.9.2)
# Requirement already satisfied: anyio in c:\users\vemer\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\vemer\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\vemer\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.6)
# Requirement already satisfied: idna in c:\users\vemer\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.10)
# Requirement already satisfied: sniffio in c:\users\vemer\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\vemer\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vemer\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\vemer\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\vemer\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama

# Initialize the client
client = ollama.Client()

def generate_insights(df_summary):
    messages = []
    prompt = f"Analyze the dataset summary and provide insights:\n\n{df_summary}"
    messages.append({'role': 'user', 'content': prompt})
    #messages.append({'role': 'user', 'content': "Analyze the dataset summary and provide insights'?"})
    response = client.chat(
        model="DeepSeek-R1",
        messages=messages
    )
    return response['message']['content']

# Generate AI Insights
summary = df.describe().to_string()
insights = generate_insights(summary)
print("\n AI-Generated Insights:\n", insights)
# Out:
#  AI-Generated Insights:
#  <think>
# Alright, I'm looking at this dataset summary for the Titanic passengers. First off, all the columns have exactly 891 entries with no missing data. That's good to know because it means there are no NaN values we need to handle.
#
# Looking at the 'Survived' column, only about 38% survived. So that's a pretty low survival rate overall. It would be interesting to see if this correlates with other factors like class or age.
#
# The average passenger was around 44 years old, but it varies quite a bit—over 14 years on either side of the mean. A lot of people are in their early thirties too. The median age is exactly the same as the first quartile, which suggests that ages are mostly clustered below 29.
#
# Most passengers are traveling alone since both 'SibSp' and 'Parch' have a lot of zeros. Only about 5% have siblings or parents with them. That's interesting; maybe it reflects real-life behavior where many people don't travel with family on such trips.
#
# The fare is mostly under $10, which makes sense for economy class. But the maximum fare is over $500, so there was a wide range of ticket prices. The median and first quartile are both around $7-8, which suggests that most passengers paid in that bracket.
#
# Looking at the classes—most were in third class with about 60% in Pclass 3. Only a small percentage were in first or second class, probably indicating that higher classes were less common on this particular trip.
#
# Survived rate varies across classes; lower survival rates are expected since third class had more than half of its passengers survive while first and second actually lost more people than third. So, higher classes might have had stricter safety measures?
#
# The fare correlates with Pclass—higher classes paid more, as expected. Also, middle to upper-middle fares tend to be linked with the number of family members sometimes.
#
# I wonder how these variables interact. For example, looking at younger passengers (below 30), about half survived. Maybe they had better luck? It's also possible that women and children had higher survival rates overall based on historical data.
#
# Since there are no missing values, I don't have to worry about imputing any data, but maybe in the future analysis, looking into how these variables relate could provide more insights.
# </think>
#
# ### Dataset Summary Analysis:
#
# The dataset contains information about 891 passengers on the Titanic. Below is a breakdown of key observations from the summary statistics provided:
#
# #### **Passenger Count:**
# - All columns (e.g., `Survived`, `Pclass`, `Age`, etc.) have exactly 891 entries with no missing data.
#
# #### **Survival Rate:**
# - Only approximately 38% of passengers survived. This suggests that the survival rate was relatively low overall, which is consistent with historical knowledge of the Titanic disaster.
#
# #### **Passenger Age Distribution:**
# - The average (mean) age of passengers was 44.6 years.
# - The standard deviation in age was around 14.5 years, indicating a wide range of ages among passengers.
# - Approximately 25% of passengers were under the age of 20, while half of the passengers were between 28 and 44 years old.
#
# #### **Travel Arrangements:**
# - Most passengers traveled alone (both `SibSp` and `Parch` columns had a mean of approximately 0.5).
# - Only about 5% of passengers had siblings or parents traveling with them.
# - This suggests that most passengers were single travelers, which is an interesting observation.
#
# #### **Fare Distribution:**
# - The average fare paid was $32.20.
# - A significant number of passengers paid very low fares (median and first quartile around $7-$8).
# - However, there was a wide range of fares, with the maximum fare being over $500. This indicates that there were both economy-class passengers and possibly higher-tier travelers.
#
# #### **Class Distribution:**
# - The majority of passengers (approximately 61%) were in the third class (`Pclass = 3`).
# - A small percentage of passengers were in first and second classes.
# - This distribution suggests that most passengers were traveling in economy class, while a smaller number traveled in higher classes.
#
# #### **Correlation Between Variables:**
# - There appears to be some correlation between `Pclass`, `Age`, and `Fare`. For example:
#   - Lower classes (`Pclass = 3`) had both lower survival rates and younger passengers on average.
#   - Higher classes (`Pclass = 1` and `Pclass = 2`) included older passengers, who might have had a higher chance of survival.
#
# #### **Potential Insights:**
# - The low survival rate overall suggests that the Titanic struck an unfortunate balance between safety for some and risk for others.
# - The presence of very high fares indicates that there were luxury passengers traveling on the ship, which is unusual given the historical context. This could suggest that the dataset includes data from a later reconstruction or that it's not entirely representative of the actual passenger list.
#
# ### **Conclusion:**
# The dataset provides valuable insights into the demographics and travel arrangements of the passengers on the Titanic. The low survival rate, age distribution, fare range, and class composition all contribute to understanding the dynamics of who was on board during the disaster.

# %%
import gradio as gr
file = r"C:\Users\vemer\Downloads\titanic dataset.csv"
def eda_analysis(file):
    df = pd.read_csv(file)
    summary = df.describe().to_string()
    insights = generate_insights(summary)
    return insights
demo = gr.Interface(fn=eda_analysis, inputs="file", outputs="text")
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
